# %%
from bnlp import NER
bn_ner = NER()
model_path = "bn_ner.pkl"
text = "আমার নাম রাজদীপ।"
result = bn_ner.tag(model_path, text)
print(result)
# Out:
# [('আমার', 'S-PER'), ('নাম', 'O'), ('রাজদীপ', 'O')]

# %%
from bnlp import NER
bn_ner = NER()
model_path = "bn_ner.pkl"
text = "আমার নাম রাজদীপ। আমি কলকাতায় থাকি।"
result = bn_ner.tag(model_path, text)
print(result)
# Out:
# [('আমার', 'S-PER'), ('নাম', 'O'), ('রাজদীপ', 'O'), ('আমি', 'S-PER'), ('কলকাতায়', 'S-LOC'), ('থাকি', 'O')]

# %%
from bnlp import NER
bn_ner = NER()
model_path = "bn_ner.pkl"
text = "আমার নাম রাজদীপ। আমি কলকাতায় থাকি। আমার দেশ ভারত. দিল্লি ভারতের রাজধানী।"
result = bn_ner.tag(model_path, text)
print(result)
# Out:
# [('আমার', 'S-PER'), ('নাম', 'O'), ('রাজদীপ', 'O'), ('আমি', 'S-PER'), ('কলকাতায়', 'S-LOC'), ('থাকি', 'O'), ('আমার', 'S-PER'), ('দেশ', 'O'), ('ভারত', 'S-LOC'), ('দিল্লি', 'S-LOC'), ('ভারতের', 'S-LOC'), ('রাজধানী', 'O')]

# %%
from bnlp import NER
bn_ner = NER()
model_path = "bn_ner.pkl"
text = "আমার নাম রাজদীপ। আমি কলকাতায় থাকি। ভারত আমার মাতৃভূমি। দিল্লি ভারতের রাজধানী। আমি বিশ্ববিদ্যালয়ে কম্পিউটার অ্যাপ্লিকেশন অধ্যয়ন করি।"
result = bn_ner.tag(model_path, text)
print(result)
# Out:
# [('আমার', 'S-PER'), ('নাম', 'O'), ('রাজদীপ', 'O'), ('আমি', 'S-PER'), ('কলকাতায়', 'S-LOC'), ('থাকি', 'O'), ('ভারত', 'S-LOC'), ('আমার', 'S-PER'), ('মাতৃভূমি', 'S-PER'), ('দিল্লি', 'S-LOC'), ('ভারতের', 'S-LOC'), ('রাজধানী', 'O'), ('আমি', 'S-PER'), ('বিশ্ববিদ্যালয়ে', 'S-ORG'), ('কম্পিউটার', 'S-OBJ'), ('অ্যাপ্লিকেশন', 'O'), ('অধ্যয়ন', 'O'), ('করি', 'O')]

# %%
from bnlp import NER
bn_ner = NER()
model_path = "bn_ner.pkl"
text = "আমি পশ্চিমবঙ্গে থাকি। বাংলা একটি মিষ্টি ভাষা। বাংলা ভাষা লন্ডনে স্বীকৃত। আমি বাংলাকে নিয়ে গর্বিত। আমি আমার ভারত মাতা নিয়ে গর্বিত। ভারত বিশ্বের এক অনন্য দেশ।"
result = bn_ner.tag(model_path, text)
print(result)
# Out:
# [('আমি', 'S-PER'), ('পশ্চিমবঙ্গে', 'O'), ('থাকি', 'O'), ('বাংলা', 'O'), ('একটি', 'O'), ('মিষ্টি', 'O'), ('ভাষা', 'O'), ('বাংলা', 'O'), ('ভাষা', 'O'), ('লন্ডনে', 'S-LOC'), ('স্বীকৃত', 'O'), ('আমি', 'S-PER'), ('বাংলাকে', 'S-LOC'), ('নিয়ে', 'O'), ('গর্বিত', 'O'), ('আমি', 'S-PER'), ('আমার', 'S-PER'), ('ভারত', 'S-LOC'), ('মাতা', 'S-PER'), ('নিয়ে', 'O'), ('গর্বিত', 'O'), ('ভারত', 'S-LOC'), ('বিশ্বের', 'S-LOC'), ('এক', 'O'), ('অনন্য', 'O'), ('দেশ', 'O')]

# %%
from bnlp import NER
bn_ner = NER()
model_path = "bn_ner.pkl"
text = "জগদীশ চন্দ্র বসুর জন্ম হয়েছিল সম্ভ্রান্ত বাঙালি কায়াস্থ পরিবারে তার পারিবারিক বাসস্থান ও জন্মস্থান হল মুন্সীগঞ্জ জেলার রাঢ়ীখাল গ্রামে (এই অঞ্চলটি বিক্রমপুর নামেও বহুল পরিচিত)তার জন্মহয় ৩০ নভেম্বর ১৮৫৮ সালে, তার পিতাম নাম ছিল ভগবান চন্দ্রা বসু ও মাতার নাম ছিল বামা সুন্দরী বসু, বিজ্ঞানী বসুর পিতা কর্মসূত্রে ছিলেন একজন ডেপুটি মেজিস্ট্রিট ও অ্যাসিস্ট্যান্ট কমিশনার প্রাথমিক কর্মস্থান ফরিদপুর ও পরে বর্ধমান ও বিভিন্ন জায়গায় নিযুক্ত ছিলেন।বোসের প্রাথমিক শিক্ষাজীবন শুরু হয়েছিল তার স্থানীয় একটি বিদ্যালয়ে বাংলা ভাষায় কারণ তার বাবা বিশ্বাস করতেন সকলকে ইংরেজিতে শিক্ষা অর্জনের পূর্বে তার মাতৃ ভাষায় শিক্ষিত হতে হয় যান এবং তার সংস্কৃতির মানুষদের জানতে ও ভালোবাসতে হয়।"
result = bn_ner.tag(model_path, text)
print(result)
# Out:
# [('জগদীশ', 'B-PER'), ('চন্দ্র', 'I-PER'), ('বসুর', 'E-PER'), ('জন্ম', 'O'), ('হয়েছিল', 'O'), ('সম্ভ্রান্ত', 'O'), ('বাঙালি', 'O'), ('কায়াস্থ', 'O'), ('পরিবারে', 'O'), ('তার', 'S-PER'), ('পারিবারিক', 'O'), ('বাসস্থান', 'O'), ('ও', 'O'), ('জন্মস্থান', 'O'), ('হল', 'O'), ('মুন্সীগঞ্জ', 'B-LOC'), ('জেলার', 'E-LOC'), ('রাঢ়ীখাল', 'B-LOC'), ('গ্রামে', 'E-LOC'), ('এই', 'O'), ('অঞ্চলটি', 'O'), ('বিক্রমপুর', 'S-LOC'), ('নামেও', 'O'), ('বহুল', 'O'), ('পরিচিত', 'O'), ('তার', 'O'), ('জন্মহয়', 'O'), ('৩০', 'O'), ('নভেম্বর', 'O'), ('১৮৫৮', 'O'), ('সালে', 'O'), ('তার', 'S-PER'), ('পিতাম', 'S-PER'), ('নাম', 'O'), ('ছিল', 'O'), ('ভগবান', 'O'), ('চন্দ্রা', 'B-PER'), ('বসু', 'E-PER'), ('ও', 'O'), ('মাতার', 'S-PER'), ('নাম', 'O'), ('ছিল', 'O'), ('বামা', 'O'), ('সুন্দরী', 'B-PER'), ('বসু', 'E-PER'), ('বিজ্ঞানী', 'B-PER'), ('বসুর', 'E-PER'), ('পিতা', 'S-PER'), ('কর্মসূত্রে', 'O'), ('ছিলেন', 'O'), ('একজন', 'O'), ('ডেপুটি', 'O'), ('মেজিস্ট্রিট', 'O'), ('ও', 'O'), ('অ্যাসিস্ট্যান্ট', 'O'), ('কমিশনার', 'O'), (
# ...

# %%
from bnlp import NER
bn_ner = NER()
model_path = "bn_ner.pkl"
text = "পৃথিবীতে থাকা প্রতিটা গাছের ও যে প্রাণ রয়েছে সেটির উপরে গবেষণা করেন স্যার জগদীশ চন্দ্র বসু। তিনি বৈজ্ঞানিক গবেষণার মাধ্যমে আবিষ্কার করেন প্রতিটা গাছ ও লতা গুল্মের ও অনুভূতি রয়েছে তারা ও প্রকৃতির বিভিন্ন আচরণে অনুভূতি প্রকাশ করেন।তাদের মধ্যে ও সুখ ও কষ্টের অনুভূতি মানুষের মতোই প্রকাশ পায়। এই গবেষণা তিনি বৈজ্ঞানিক ভাবে সারাবিশ্বের কাছে তুলে ধরেন এবং তুমুল জনপ্রিয়তা আর সম্মান প্রাপ্ত করেন।"
result = bn_ner.tag(model_path, text)
print(result)
# Out:
# [('পৃথিবীতে', 'S-LOC'), ('থাকা', 'O'), ('প্রতিটা', 'O'), ('গাছের', 'O'), ('ও', 'O'), ('যে', 'O'), ('প্রাণ', 'O'), ('রয়েছে', 'O'), ('সেটির', 'O'), ('উপরে', 'O'), ('গবেষণা', 'O'), ('করেন', 'O'), ('স্যার', 'S-PER'), ('জগদীশ', 'B-PER'), ('চন্দ্র', 'I-PER'), ('বসু', 'E-PER'), ('তিনি', 'S-PER'), ('বৈজ্ঞানিক', 'O'), ('গবেষণার', 'O'), ('মাধ্যমে', 'O'), ('আবিষ্কার', 'O'), ('করেন', 'O'), ('প্রতিটা', 'O'), ('গাছ', 'O'), ('ও', 'O'), ('লতা', 'O'), ('গুল্মের', 'O'), ('ও', 'O'), ('অনুভূতি', 'O'), ('রয়েছে', 'O'), ('তারা', 'S-PER'), ('ও', 'O'), ('প্রকৃতির', 'O'), ('বিভিন্ন', 'O'), ('আচরণে', 'O'), ('অনুভূতি', 'O'), ('প্রকাশ', 'O'), ('করেন', 'O'), ('তাদের', 'S-PER'), ('মধ্যে', 'O'), ('ও', 'O'), ('সুখ', 'O'), ('ও', 'O'), ('কষ্টের', 'O'), ('অনুভূতি', 'O'), ('মানুষের', 'S-PER'), ('মতোই', 'O'), ('প্রকাশ', 'O'), ('পায়', 'O'), ('এই', 'O'), ('গবেষণা', 'O'), ('তিনি', 'S-PER'), ('বৈজ্ঞানিক', 'O'), ('ভাবে', 'O'), ('সারাবিশ্বের', 'O'), ('কাছে', 'O'), ('তুলে', 'O'), ('ধরেন', 'O'), ('এবং', 'O'), ('তুমুল', 'O'), ('জ
# ...
